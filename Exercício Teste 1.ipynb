# %% [markdown]
# # Exercício Teste 1 - E1

# %% [markdown]
# Exercício com data de entrega para 6 de março de 2021.
#
#
# Aluno: Noé de Lima Bezerra
# Matrícula: 816.037.029
#
# <noe_lima@id.uff.br>

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from IPython.display import display, Math, Image, IFrame
#from sympy.abc import x, y, z
sp.init_printing(use_latex='mathjax',latex_mode='equation*')

# %% [markdown]
# # Questão 1

# %% [markdown]
# Determine para a estrutura indicada:
#
# 1. Os diagramas de <b>esforços internos ($M$) e ($Q$) e as reações de apoio</b> para a viga contínua hiperestática e
# o carregamento indicado <b>utilizando o Método das Forças</b>.
#
# 2. Resolver o problema (estrutura original hiperestática) usando o programa Ftool e analisar os resultados
# comparando com a solução pelo Método das Forças. Anexar na prova os diagramas encontrados no Ftool.
#
# Dados das barras:
#
# Inércias
#
# * $J(barra\ 1) = J(barra\ 2) = 0,0030 m^{4}$
#
# * $J(barra\ 3)= 0,0040 m^{4}$
#
# Atenção: Para o valor de $X$ nas cargas aplicadas deve ser utilizado o último número de sua matrícula.

# %%
Image("Figuras/ex1.png")

# %% [markdown]
# ## Solução

# %% [markdown]
# Desenvolver...

# %% [markdown]
# # Questão 2

# %% [markdown]
# Determine para a estrutura indicada:
#
# 1. Os diagramas de <b>esforços internos ($M$), ($Q$) e ($N$) e as reações de apoio</b> para o quadro hiperestático e o carregamento indicado <b>utilizando o Método das Forças</b>.
#
# 2. Resolver o problema (estrutura original hiperestática) usando o programa Ftool e analisar os resultados comparando com a solução pelo Método das Forças. Anexar na prova os diagramas encontrados no Ftool.
#
# Dados das barras: Todas as barras tem a mesma inércia ($J$).
#
# Atenção: Para o valor de $XX$ na carga aplicada devem ser utilizados os dois últimos números de sua matrícula.

# %%
Image("Figuras/ex2.png")

# %% [markdown]
# ## Solução

# %% [markdown]
# Desenvolver
